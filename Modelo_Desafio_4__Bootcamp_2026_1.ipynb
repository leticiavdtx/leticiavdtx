# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiavdtx/leticiavdtx/blob/main/Modelo_Desafio_4__Bootcamp_2026_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DESAFIO 1
#
# Imagine que você recebeu uma resposta de uma pesquisa sobre as ferramentas favoritas de uma desenvolvedora, no formato de um dicionário Python. Sua tarefa é extrair e exibir as linguagens de programação que ela listou.
#
# Percorra a lista de linguagens_favoritas dentro do dicionário e imprima cada uma delas.

# %%
resposta_pesquisa = {
    "nome": "Camila",
    "idade": 28,
    "cargo": "Cientista de Dados",
    "linguagens_favoritas": ["Python", "SQL", "R"],
    "ferramentas_bi": ["Tableau", "Power BI"]
}

# %%
#Execute seu código aqui

# %% [markdown]
# DESAFIO 2
#
# Crie um programa que percorra uma lista de participantes e exiba apenas aquelas interessadas em "Ciência de Dados".

# %%
participantes = [
    {"nome": "Ana", "area": "BI"},
    {"nome": "Bruna", "area": "Ciência de Dados"},
    {"nome": "Carla", "area": "BI"},
    {"nome": "Daniela", "area": "Engenharia de Dados"},
    {"nome": "Eduarda", "area": "BI"},
    {"nome": "Fernanda", "area": "Ciência de Dados"},
    {"nome": "Gabriela", "area": "BI"},
    {"nome": "Helena", "area": "Engenharia de Dados"},
    {"nome": "Isabela", "area": "BI"},
    {"nome": "Juliana", "area": "Ciência de Dados"},
    {"nome": "Karina", "area": "BI"},
    {"nome": "Larissa", "area": "Engenharia de Dados"}
]

# %%
#Execute seu código aqui

# %% [markdown]
# DESAFIO 3
#
# Durante o cadastro, é necessário validar se o e-mail informado contém os caracteres "@" e ".".
#
# Crie um programa que leia um e-mail e informe se ele é válido ou inválido.

# %%
#Execute seu código aqui

# %% [markdown]
# DESAFIO 4
#
# Após um evento, as participantes deixaram avaliações em texto.
#
# Crie um programa que conte quantas avaliações contêm palavras positivas como "bom", "ótimo" ou "excelente".

# %%
#Execute seu código aqui

# %% [markdown]
# DESAFIO 5
#
# Crie uma função que receba uma lista de números e retorne:
#
# quantidade de valores
#
# soma
#
# média
#
# maior valor
#
# menor valor

# %%
#Execute seu código aqui
